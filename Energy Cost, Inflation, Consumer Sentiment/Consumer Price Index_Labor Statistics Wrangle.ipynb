# %% [markdown]
# # Consumer Price Index
#
# The datasets represented in this jupyter notebook are from the Bureau of Labor Statistics:
#  - [Top Picks for Consumer Prices](https://data.bls.gov/cgi-bin/surveymost?ap)
#
# This dataset represents consumer prices that are common purchases for the United States populace. Having a reflection of price changes throughout the last two decades will help glean insights into what changes in pricing do to over consumer sentiment in the economy. Below you will find a wrangling process to clean a dataset that will be joined to consumer sentiment index, inflation, and energy information to determine a narrow, but holistic review of consumer sentiment sensitivity.

# %%
# Libraries used for this wrangling effort.

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from datetime import date

# %% [markdown]
# Loading the dataset into the cpi variable

# %%
cpi = pd.read_csv(r'C:\Users\stanl\OneDrive\Documents\Graduate School\Regis_Practicum_1\CPI Average Price Data.csv')

# %%
# previewing the data
cpi.head()
# Out:
#          Date  APU0000704111 Original Data Value  \
# 0  1990-01-01                              1.966
# 1  1990-02-01                              2.009
# 2  1990-03-01                              1.991
# 3  1990-04-01                              1.979
# 4  1990-05-01                              2.044
#
#    APU0000704111 1-Month Percent Change  APU0000704111 3-Month Percent Change  \
# 0                                   0.5                                  11.2
# 1                                   2.2                                  10.4
# 2                                  -0.9                                   1.8
# 3                                  -0.6                                   0.7
# 4                                   3.3                                   1.7
#
#    APU0000704111 12-Month Percent Change  APU0000711211 Original Data Value  \
# 0                                    8.9                              0.429
# 1                                   11.7                              0.492
# 2                                   11.4                              0.500
# 3                                   13.3                              0.481
# 4                                   21.7                              0.462
#
#    APU0000711211 1-Month Percent Change  APU0000711211 3-Month Percent Change  \
# 0                                   3.1                                  -0.7
# 1                                  14.7                                  13.1
# 2                                   1.6                                  20.2
# 3                                  -3.8                                  12.1
# 4                                  -4.0                                  -6.1
#
#    APU0000711211 12-Month Percent Change  APU0000702111 Original Data Value  \
# 0                                    8.9                              0.689
# 1                                   18.6                              0.701
# 2                                   11.1                              0.680
# 3                                   -8.0                              0.686
# 4                                  -11.5                              0.678
#
#    ...  APU000072511 3-Month Percent Change  \
# 0  ...                                 41.9
# 1  ...                                 12.0
# 2  ...                                  0.9
# 3  ...                                -23.1
# 4  ...                                 -6.9
#
#    APU000072511 12-Month Percent Change  APU00007471A Original Data Value  \
# 0                                  42.6                             1.090
# 1                                  15.2                             1.086
# 2                                  10.8                             1.076
# 3                                   7.1                             1.096
# 4                                   7.3                             1.114
#
#    APU00007471A 1-Month Percent Change  APU00007471A 3-Month Percent Change  \
# 0                                  5.8                                  1.8
# 1                                 -0.4                                  3.8
# 2                                 -0.9                                  4.5
# 3                                  1.9                                  0.6
# 4                                  1.6                                  2.6
#
#    APU00007471A 12-Month Percent Change  APU000074714 Original Data Value  \
# 0                                  15.5                             1.042
# 1                                  13.7                             1.037
# 2                                  10.5                             1.023
# 3                                  -0.2                             1.044
# 4                                  -3.3                             1.061
#
#    APU000074714 1-Month Percent Change  APU000074714 3-Month Percent Change  \
# 0                                  6.3                                  1.5
# 1                                 -0.5                                  3.8
# 2                                 -1.4                                  4.4
# 3                                  2.1                                  0.2
# 4                                  1.6                                  2.3
#
#    APU000074714 12-Month Percent Change
# 0                                  13.5
# 1                                  12.0
# 2                                   8.8
# 3                                  -2.0
# 4                                  -5.2
#
# [5 rows x 61 columns]

# %% [markdown]
# Checking shape - there are 384 rows, 61 columns

# %%
cpi.shape
# Out:
# (384, 61)

# %%
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total
#  38  APU0000701312 1-Month Percent Change   354 non-null    float64
#  39  APU0000701312 3-Month Percent Change   352 non-null    float64
#  40  APU0000701312 12-Month Percent Change  343 non-null    float64
#  41  APU0000712311 Original Data Value      378 non-null    float64
#  42  APU0000712311 1-Month Percent Change   376 non-null    float64
#  43  APU0000712311 3-Month Percent Change   375 non-null    float64
#  44  APU0000712311 12-Month Percent Change  375 non-null    float64
#  45  APU000072610 Original Data Value       381 non-null    float64
#  46  APU000072610 1-Month Percent Change    381 non-null    float64
#  47  APU000072610 3-Month Percent Change    381 non-null    float64
#  48  APU000072610 12-Month Percent Change   381 non-null    float64
#  49  APU000072511 Original Data Value       381 non-null    float64
#  50  APU000072511 1-Month Percent Change    381 non-null    float64
#  51  APU000072511 3-Month Percent Change    381 non-null    float64
#  52  APU000072511 12-Month Percent Change   381 non-null    float64
#  53  APU00007471A Original Data Value       381 non-null    float64
#  54  APU00007471A 1-Month Percent Change    381 non-null    float64
#  55  APU00007471A 3-Month Percent Change    381 non-null    float64
#  56  APU00007471A 12-Month Percent Change   381 non-null    float64
#  57  APU000074714 Original Data Value       381 non-null    float64
#  58  APU000074714 1-Month Percent Change    381 non-null    float64
#  59  APU000074714 3-Month Percent Change    381 non-null    float64
#  60  APU000074714 12-Month Percent Change   381 non-null    float64
# dtypes: datetime64[ns](1), float64(60)
# memory usage: 183.1 KB

# %%
# cpi.set_index('Date', drop=True, inplace=True)

# %% [markdown]
# ### Adressing Column Names
#
# To clear confusion of labels I will change all names to their proper categories. APU### is directly from the Bureau of Labor Statistics website. This will be used moving forward in all joins, EDA, and wrangling work.

# %%
cpi.columns = cpi.columns.str.replace('APU0000704111', 'Bacon')
cpi.columns = cpi.columns.str.replace('APU0000711211', 'Bananas')
cpi.columns = cpi.columns.str.replace('APU0000702111', 'Bread')
cpi.columns = cpi.columns.str.replace('APU0000706111', 'Chicken')
cpi.columns = cpi.columns.str.replace('APU0000717311', 'Coffee')
cpi.columns = cpi.columns.str.replace('APU0000708111', 'Eggs')
cpi.columns = cpi.columns.str.replace('APU0000701111', 'Flour')
cpi.columns = cpi.columns.str.replace('APU0000709112', 'Milk')
cpi.columns = cpi.columns.str.replace('APU0000711311', 'Oranges')
cpi.columns = cpi.columns.str.replace('APU0000701312', 'Rice')
cpi.columns = cpi.columns.str.replace('APU0000712311', 'Tomatoes')
cpi.columns = cpi.columns.str.replace('APU000072610', 'Electricity_CPI')
cpi.columns = cpi.columns.str.replace('APU000072511', 'Fuel_Oil_#2')
cpi.columns = cpi.columns.str.replace('APU00007471A', 'Gasoline_all_types')
cpi.columns = cpi.columns.str.replace('APU000074714', 'Gasoline_unleaded')

# %% [markdown]
# Confirmation of changes

# %%
cpi.head()
# Out:
#         Date  Bacon Original Data Value  Bacon 1-Month Percent Change  \
# 0 1990-01-01                      1.966                           0.5
# 1 1990-02-01                      2.009                           2.2
# 2 1990-03-01                      1.991                          -0.9
# 3 1990-04-01                      1.979                          -0.6
# 4 1990-05-01                      2.044                           3.3
#
#    Bacon 3-Month Percent Change  Bacon 12-Month Percent Change  \
# 0                          11.2                            8.9
# 1                          10.4                           11.7
# 2                           1.8                           11.4
# 3                           0.7                           13.3
# 4                           1.7                           21.7
#
#    Bananas Original Data Value  Bananas 1-Month Percent Change  \
# 0                        0.429                             3.1
# 1                        0.492                            14.7
# 2                        0.500                             1.6
# 3                        0.481                            -3.8
# 4                        0.462                            -4.0
#
#    Bananas 3-Month Percent Change  Bananas 12-Month Percent Change  \
# 0                            -0.7                              8.9
# 1                            13.1                             18.6
# 2                            20.2                             11.1
# 3                            12.1                             -8.0
# 4                            -6.1                            -11.5
#
#    Bread Original Data Value  ...  Fuel_Oil_#2 3-Month Percent Change  \
# 0                      0.689  ...                                41.9
# 1                      0.701  ...                                12.0
# 2                      0.680  ...                                 0.9
# 3                      0.686  ...                               -23.1
# 4                      0.678  ...                                -6.9
#
#    Fuel_Oil_#2 12-Month Percent Change  \
# 0                                 42.6
# 1                                 15.2
# 2                                 10.8
# 3                                  7.1
# 4                                  7.3
#
#    Gasoline_all_types Original Data Value  \
# 0                                   1.090
# 1                                   1.086
# 2                                   1.076
# 3                                   1.096
# 4                                   1.114
#
#    Gasoline_all_types 1-Month Percent Change  \
# 0                                        5.8
# 1                                       -0.4
# 2                                       -0.9
# 3                                        1.9
# 4                                        1.6
#
#    Gasoline_all_types 3-Month Percent Change  \
# 0                                        1.8
# 1                                        3.8
# 2                                        4.5
# 3                                        0.6
# 4                                        2.6
#
#    Gasoline_all_types 12-Month Percent Change  \
# 0                                        15.5
# 1                                        13.7
# 2                                        10.5
# 3                                        -0.2
# 4                                        -3.3
#
#    Gasoline_unleaded Original Data Value  \
# 0                                  1.042
# 1                                  1.037
# 2                                  1.023
# 3                                  1.044
# 4                                  1.061
#
#    Gasoline_unleaded 1-Month Percent Change  \
# 0                                       6.3
# 1                                      -0.5
# 2                                      -1.4
# 3                                       2.1
# 4                                       1.6
#
#    Gasoline_unleaded 3-Month Percent Change  \
# 0                                       1.5
# 1                                       3.8
# 2                                       4.4
# 3                                       0.2
# 4                                       2.3
#
#    Gasoline_unleaded 12-Month Percent Change
# 0                                       13.5
# 1                                       12.0
# 2                                        8.8
# 3                                       -2.0
# 4                                       -5.2
#
# [5 rows x 61 columns]

# %% [markdown]
# Checking null values to see what may need to be addressed. I will address null values when all joins are complete into the final dataset.

# %%
(cpi.isnull().sum()/len(cpi)).sort_values(ascending=False)
# Out:
# Oranges 3-Month Percent Change     0.367188
# Oranges 1-Month Percent Change     0.286458
# Oranges 12-Month Percent Change    0.270833
# Oranges Original Data Value        0.231771
# Milk 12-Month Percent Change       0.210938
#                                      ...
# Bread 12-Month Percent Change      0.007812
# Eggs Original Data Value           0.007812
# Eggs 1-Month Percent Change        0.007812
# Eggs 3-Month Percent Change        0.007812
# Date                               0.000000
# Length: 61, dtype: float64

# %% [markdown]
# Briefly, we can see that oranges are the highest percentage of null values that will need to be addressed later.

# %%
cpi.to_csv('CPI_cleaned.csv')

# %% [markdown]
# This cleaned version of Consumer Price Index will now be exported to a CSV for futre joining to the other datasets to complete the wrangle. The next step will be joining EIA, CPI, and INF (inflation index).
